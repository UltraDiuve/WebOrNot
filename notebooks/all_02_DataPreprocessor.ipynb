# %% [markdown]
# # 1. Objet
#
# Ce script retraite les données brutes enregistrées par le RawDataProcessor afin de :
# - contrôler la conformité à certaines règles de gestion métier
# - nettoyer les avoirs lorsque c'est possible
# - agréger les informations à une maille commande
# - calculer le canal majoritaire en poids
# - effectuer d'autres aggrégations si nécessaire (ex : types de tarif...)

# %% [markdown]
# # 2. Imports et setup technique

# %%
from pathlib import Path
import sys
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from importlib import reload
project_root = str(Path(sys.path[0]).parents[0].absolute())
project_root
if project_root not in sys.path:
    sys.path.append(project_root)
import multiprocessing as mp
    
from scripts.utils import process_df  # traitement des avoirs
    
data_path = Path('..') / 'data'
persist_path = Path('..') / 'persist'
from IPython.display import display, HTML
display(HTML("<style>.container { width:90%; }</style>"))

from dask.distributed import LocalCluster, Client
import dask.dataframe as dd
client = Client(
    n_workers=int(0.9 * mp.cpu_count()),
    processes=True,
    threads_per_worker=1,
    dashboard_address=':35000'
) # n_workers=1, threads_per_worker=4, processes=False, memory_limit='2GB'
client
# Out:
# <style>.container { width:90%; }</style>
# <Client: 'tcp://127.0.0.1:34540' processes=7 threads=7, memory=33.56 GB>

# %%
orgacom_list = [
    '1ALO',
    '1BFC',
    '1CAP',
    '1CTR',
    '1EXP',
    '1LRO',
    '1LXF',
    '1NCH',
    '1OUE',
    '1PAC',
#     '1PLU', 
    '1PNO',
    '1PSU',
    '1RAA',
    '1SOU',
    '2BRE',
    '2CAE',
    '2CTR',
    '2EST',
    '2IDF',
#     '2IFC', Cash Européenne Food ?
    '2MPY',
    '2NOR',
    '2RAA',
    '2SES',
    '2SOU',
]

# %% [markdown]
# # Chargement des données brutes

# %%
# %%time
with LocalCluster(
    n_workers=int(0.9 * mp.cpu_count()),
    processes=True,
    threads_per_worker=1,
    dashboard_address=':36000',
#     memory_limit='2GB',
#     ip='tcp://localhost:9895',
) as cluster, Client(cluster) as client_:
    raw_data = dd.read_parquet(persist_path / 'raw_data.parquet')
    print(f'Il y a {len(raw_data)} lignes dans le dataset')
# Out:
# Il y a 229941217 lignes dans le dataset
# CPU times: user 1.29 s, sys: 243 ms, total: 1.53 s
# Wall time: 4.9 s

# %%
# timed : 6,45s

# %%time
# with LocalCluster(
#     n_workers=int(0.9 * mp.cpu_count()),
#     processes=False,
#     threads_per_worker=1,
#     dashboard_address=':36000',
# #     memory_limit='2GB',
# #     ip='tcp://localhost:9895',
# ) as cluster, Client(cluster) as client_:
#     raw_data = dd.read_parquet(persist_path / 'raw_data.parquet')
#     print(f'Il y a {len(raw_data)} lignes dans le dataset')

# %% [markdown]
# Il est nécessaire de recharger les catégories à la lecture du fichier parquet.
# https://docs.dask.org/en/latest/dataframe-categoricals.html

# %%
for field in raw_data.dtypes.loc[lambda x: x == 'category'].index:
    raw_data[field] = raw_data[field].cat.set_categories(raw_data[field].head(1).cat.categories)

# %% [markdown]
# # Contrôle des données
#
# On définit les fonctions qui vont permettre d'effectuer les contrôles.
#
# ### Contrôle des types de documents

# %%
valid_doctypes = ['ZC01', 'ZC02', 'ZC10'] # documents de type "commandes"
invalid_doctypes = ['ZR01', 'ZR02', 'ZA01', 'ZA02', 'ZA03', 'ZA04', 'ZC20']  # autres types de documents
doctypes = valid_doctypes + invalid_doctypes

# %% [markdown]
# On s'assure qu'on n'a pas de type de document non prévu.

# %%
def ctrle_doctypes(data):
    if len(data.loc[~data.doctype.isin(doctypes)]) > 0:
        print(f'Unexpected doctypes have been encountered: '
              f'{data.loc[~data.doctype.isin(doctypes), "doctype"].value_counts().compute()}!')

# %%
# %%time
with LocalCluster(
    n_workers=int(0.9 * mp.cpu_count()),
    processes=True,
    threads_per_worker=1,
    dashboard_address=':36000',
#     memory_limit='2GB',
#     ip='tcp://localhost:9895',
) as cluster, Client(cluster) as client_:    
    ctrle_doctypes(raw_data)
# Out:
# Unexpected doctypes have been encountered: #      959834
# ZB1       874
# ZB5       435
# Name: doctype, dtype: int64!
# CPU times: user 14 s, sys: 1.81 s, total: 15.8 s
# Wall time: 2min

# %%
# timed to 8min 11s => mainly python code, should use processes.

# %%time
# with LocalCluster(
#     n_workers=int(0.9 * mp.cpu_count()),
#     processes=False,
#     threads_per_worker=1,
#     dashboard_address=':36000',
# #     memory_limit='2GB',
# #     ip='tcp://localhost:9895',
# ) as cluster, Client(cluster) as client_:    
#     ctrle_doctypes(raw_data)

# %% [markdown]
# ### Contrôle des CA bruts non nuls alors que le poids est nul
#
# D'un point de vue métier, il n'est pas possible qu'une ligne de **commande** (= valid_doctype) avec un poids nul ait un CA brut, sauf pour certains articles de service

# %% [markdown]
# Je veux : un rapport qui me sort, par succursale, les produits qui ont des lignes avec du revenue mais pas de poids, en comptant le nombre de lignes.

# %%
def ctrle_no_weight_revenue(data, order_doctypes=valid_doctypes):
    return(
        data.loc[
            data.doctype.isin(order_doctypes) &
            (data.weight == 0) &
            (data.brutrevenue != 0)
        ]
        .compute()
        .groupby(['orgacom', 'material'], observed=True)
        .size()
        .to_frame()
    )

# %%
# %%time
with LocalCluster(
    n_workers=int(0.9 * mp.cpu_count()),
    processes=True,
    threads_per_worker=1,
    dashboard_address=':36000',
#     memory_limit='2GB',
#     ip='tcp://localhost:9895',
) as cluster, Client(cluster) as client_:
    result = ctrle_no_weight_revenue(raw_data)
# Out:
# CPU times: user 9.19 s, sys: 1.12 s, total: 10.3 s
# Wall time: 1min 1s

# %%
# timed : 4min 14s

# %%time
# with LocalCluster(
#     n_workers=int(0.9 * mp.cpu_count()),
#     processes=False,
#     threads_per_worker=1,
#     dashboard_address=':36000',
# #     memory_limit='2GB',
# #     ip='tcp://localhost:9895',
# ) as cluster, Client(cluster) as client_:
#     result = ctrle_no_weight_revenue(raw_data)

# %%
with pd.option_context('display.max_columns', None):
    display(result.unstack('orgacom', fill_value=0).sort_index(axis=1).style.bar(align='mid', axis=None))
# Out:
# <style  type="text/css" >
# #T_a3f4d_row0_col0,#T_a3f4d_row0_col1,#T_a3f4d_row0_col2,#T_a3f4d_row0_col3,#T_a3f4d_row0_col4,#T_a3f4d_row0_col5,#T_a3f4d_row0_col6,#T_a3f4d_row0_col7,#T_a3f4d_row0_col8,#T_a3f4d_row0_col9,#T_a3f4d_row0_col10,#T_a3f4d_row0_col11,#T_a3f4d_row0_col12,#T_a3f4d_row0_col13,#T_a3f4d_row0_col14,#T_a3f4d_row0_col15,#T_a3f4d_row0_col16,#T_a3f4d_row0_col18,#T_a3f4d_row0_col19,#T_a3f4d_row0_col20,#T_a3f4d_row0_col21,#T_a3f4d_row1_col0,#T_a3f4d_row1_col1,#T_a3f4d_row1_col2,#T_a3f4d_row1_col3,#T_a3f4d_row1_col4,#T_a3f4d_row1_col5,#T_a3f4d_row1_col6,#T_a3f4d_row1_col7,#T_a3f4d_row1_col8,#T_a3f4d_row1_col9,#T_a3f4d_row1_col10,#T_a3f4d_row1_col12,#T_a3f4d_row1_col13,#T_a3f4d_row1_col14,#T_a3f4d_row1_col15,#T_a3f4d_row1_col16,#T_a3f4d_row1_col17,#T_a3f4d_row1_col18,#T_a3f4d_row1_col19,#T_a3f4d_row1_col20,#T_a3f4d_row1_col21,#T_a3f4d_row2_col0,#T_a3f4d_row2_col1,#T_a3f4d_row2_col2,#T_a3f4d_row2_col3,#T_a3f4d_row2_col4,#T_a3f4d_row2_col5,#T_a3f4d_row2_col6,#T_a3f4d_row2_col7,#T_a3f4d_row2_col8,#T_a3f4d_row2_col9,#T_a3f4d_row2_col10,#T_a3f4d_row2_col11,#T_a3f4d_row2_col12,#T_a3f4d_row2_col13,#T_a3f4d_row2_col14,#T_a3f4d_row2_col15,#T_a3f4d_row2_col16,#T_a3f4d_row2_col17,#T_a3f4d_row2_col19,#T_a3f4d_row2_col20,#T_a3f4d_row2_col21,#T_a3f4d_row3_col0,#T_a3f4d_row3_col1,#T_a3f4d_row3_col2,#T_a3f4d_row3_col3,#T_a3f4d_row3_col4,#T_a3f4d_row3_col5,#T_a3f4d_row3_col6,#T_a3f4d_row3_col7,#T_a3f4d_row3_col8,#T_a3f4d_row3_col9,#T_a3f4d_row3_col10,#T_a3f4d_row3_col11,#T_a3f4d_row3_col12,#T_a3f4d_row3_col13,#T_a3f4d_row3_col14,#T_a3f4d_row3_col15,#T_a3f4d_row3_col16,#T_a3f4d_row3_col17,#T_a3f4d_row3_col18,#T_a3f4d_row3_col20,#T_a3f4d_row4_col0,#T_a3f4d_row4_col1,#T_a3f4d_row4_col2,#T_a3f4d_row4_col3,#T_a3f4d_row4_col4,#T_a3f4d_row4_col5,#T_a3f4d_row4_col6,#T_a3f4d_row4_col7,#T_a3f4d_row4_col8,#T_a3f4d_row4_col9,#T_a3f4d_row4_col10,#T_a3f4d_row4_col11,#T_a3f4d_row4_col12,#T_a3f4d_row4_col13,#T_a3f4d_row4_col14,#T_a3f4d_row4_col15,#T_a3f4d_row4_col16,#T_a3f4d_row4_col17,#T_a3f4d_row4_col19,#T_a3f4d_row4_col20,#T_a3f4d_row4_col21,#T_a3f4d_row5_col0,#T_a3f4d_row5_col1,#T_a3f4d_row5_col2,#T_a3f4d_row5_col3,#T_a3f4d_row5_col4,#T_a3f4d_row5_col5,#T_a3f4d_row5_col6,#T_a3f4d_row5_col7,#T_a3f4d_row5_col8,#T_a3f4d_row5_col9,#T_a3f4d_row5_col10,#T_a3f4d_row5_col11,#T_a3f4d_row5_col12,#T_a3f4d_row5_col13,#T_a3f4d_row5_col14,#T_a3f4d_row5_col15,#T_a3f4d_row5_col16,#T_a3f4d_row5_col17,#T_a3f4d_row5_col18,#T_a3f4d_row5_col19,#T_a3f4d_row5_col21,#T_a3f4d_row6_col0,#T_a3f4d_row6_col1,#T_a3f4d_row6_col2,#T_a3f4d_row6_col3,#T_a3f4d_row6_col4,#T_a3f4d_row6_col5,#T_a3f4d_row6_col6,#T_a3f4d_row6_col7,#T_a3f4d_row6_col8,#T_a3f4d_row6_col9,#T_a3f4d_row6_col10,#T_a3f4d_row6_col11,#T_a3f4d_row6_col12,#T_a3f4d_row6_col16,#T_a3f4d_row7_col0,#T_a3f4d_row7_col1,#T_a3f4d_row7_col2,#T_a3f4d_row7_col3,#T_a3f4d_row7_col4,#T_a3f4d_row7_col5,#T_a3f4d_row7_col6,#T_a3f4d_row7_col7,#T_a3f4d_row7_col9,#T_a3f4d_row7_col10,#T_a3f4d_row7_col11,#T_a3f4d_row7_col12,#T_a3f4d_row7_col13,#T_a3f4d_row7_col14,#T_a3f4d_row7_col15,#T_a3f4d_row7_col16,#T_a3f4d_row7_col17,#T_a3f4d_row7_col18,#T_a3f4d_row7_col19,#T_a3f4d_row7_col20,#T_a3f4d_row7_col21,#T_a3f4d_row8_col0,#T_a3f4d_row8_col1,#T_a3f4d_row8_col3,#T_a3f4d_row8_col4,#T_a3f4d_row8_col5,#T_a3f4d_row8_col6,#T_a3f4d_row8_col7,#T_a3f4d_row8_col8,#T_a3f4d_row8_col9,#T_a3f4d_row8_col10,#T_a3f4d_row8_col11,#T_a3f4d_row8_col12,#T_a3f4d_row8_col13,#T_a3f4d_row8_col14,#T_a3f4d_row8_col15,#T_a3f4d_row8_col16,#T_a3f4d_row8_col17,#T_a3f4d_row8_col18,#T_a3f4d_row8_col19,#T_a3f4d_row8_col20,#T_a3f4d_row8_col21,#T_a3f4d_row9_col0,#T_a3f4d_row9_col1,#T_a3f4d_row9_col2,#T_a3f4d_row9_col3,#T_a3f4d_row9_col4,#T_a3f4d_row9_col5,#T_a3f4d_row9_col6,#T_a3f4d_row9_col9,#T_a3f4d_row9_col10,#T_a3f4d_row9_col11,#T_a3f4d_row9_col12,#T_a3f4d_row9_col13,#T_a3f4d_row9_col14,#T_a3f4d_row9_col15,#T_a3f4d_row9_col16,#T_a3f4d_row9_col17,#T_a3f4d_row9_col18,#T_a3f4d_row9_col19,#T_a3f4d_row9_col20,#T_a3f4d_row9_col21,#T_a3f4d_row10_col0,#T_a3f4d_row10_col1,#T_a3f4d_row10_col2,#T_a3f4d_row10_c ...

# %% [markdown]
# L'essentiel des articles concernés sont des articles de service (forfaits livraison). Il faudrait regarder ce qui s'est passé sur le 156486, il remonte régulièrement côté ES.

# %% [markdown]
# ### Contrôle des origines de commande

# %%
# def ctrle_origin(data, valid_origins=valid_origins):
#     report = data.loc[
#         ~data.origin.isin(valid_origins) &
#         (data.brutrevenue != 0) &
#         data.doctype.isin(valid_doctypes)
#     ].value_counts('origin').rename('counts').to_frame()
#     report['percentage'] = report['counts'] / sum(
#         (data.brutrevenue != 0) &
#         data.doctype.isin(valid_doctypes)
#     )
#     return(report.loc[report['counts'] > 0])

# %%
valid_origins = ['TV', 'VR', 'WEB', 'EDI']

def ctrle_origin(data, valid_origins=valid_origins):
    sizes = (
        data.loc[
            (data.brutrevenue != 0) &
            data.doctype.isin(valid_doctypes)
        ].groupby(['orgacom'], observed=True).size()
        .compute()
    ).rename('baseline')
    
    invalid_origins = (
        data.loc[
            (data.brutrevenue != 0) &
            data.doctype.isin(valid_doctypes) &
            ~data.origin.isin(valid_origins)
        ].groupby(['orgacom', 'origin'], observed=True).size()
        .compute()    
    ).rename('invalid').to_frame()
    invalid_origins = invalid_origins.reset_index().merge(sizes.reset_index(), on='orgacom', how='left')
    invalid_origins['percentage'] = invalid_origins['invalid'] / invalid_origins['baseline']
    return(invalid_origins)

# %%
# %%time
with LocalCluster(
    n_workers=int(0.9 * mp.cpu_count()),
    processes=True,
    threads_per_worker=1,
    dashboard_address=':36000',
#     memory_limit='2GB',
#     ip='tcp://localhost:9895',
) as cluster, Client(cluster) as client:
    display(ctrle_origin(raw_data).sort_values(['orgacom', 'origin']).style.format({'percentage': lambda x: f'{x:.2%}'}).bar(subset=['percentage'], align='mid', ))
# Out:
# <style  type="text/css" >
# #T_67db6_row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.8%, transparent 19.8%);
#         }#T_67db6_row1_col4,#T_67db6_row2_col4,#T_67db6_row17_col4,#T_67db6_row19_col4,#T_67db6_row21_col4,#T_67db6_row22_col4,#T_67db6_row42_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }#T_67db6_row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.1%, transparent 7.1%);
#         }#T_67db6_row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_67db6_row5_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.2%, transparent 4.2%);
#         }#T_67db6_row6_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.8%, transparent 9.8%);
#         }#T_67db6_row7_col4,#T_67db6_row12_col4,#T_67db6_row20_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }#T_67db6_row8_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 30.9%, transparent 30.9%);
#         }#T_67db6_row9_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.4%, transparent 8.4%);
#         }#T_67db6_row10_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.6%, transparent 5.6%);
#         }#T_67db6_row11_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.3%, transparent 8.3%);
#         }#T_67db6_row13_col4,#T_67db6_row15_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.7%, transparent 9.7%);
#         }#T_67db6_row14_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.1%, transparent 12.1%);
#         }#T_67db6_row16_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.0%, transparent 10.0%);
#         }#T_67db6_row18_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.9%, transparent 7.9%);
#         }#T_67db6_row23_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.6%, transparent 9.6%);
#         }#T_67db6_row24_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.7%, transparent 8.7%);
#         }#T_67db6_row25_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.7%, transparent 6.7%);
#         }#T_67db6_row26_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.2%, transparent 11.2%);
#         }#T_67db6_row27_col4,#T_67db6_row41_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.3%, transparent 4.3%);
#         }#T_67db6_row28_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.5%, transparent 2.5%);
#         }#T_67db6_row29_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.3%, transparent 7.3%);
#         }#T_67db6_row30_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.1%, transparent 5.1%);
#         }#T_67db6_row31_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.0%, transparent 5.0%);
#         }#T_67db6_row32_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0.8%);
#         }#T_67db6_row33_col4,#T_67db6_row37_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.0%, transparent 4.0%);
#         }#T_67db6_row34_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.4%, transparent 2.4%);
#         }#T_67db6_row35_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.5%, transparent 5.5%);
#         }#T_67db6_row36_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.3%, transparent 3.3%);
#         }#T_67db6_row38_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.5%, transparent 3.5%);
#         }#T_67db6_row39_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.9%, transparent 4.9%);
#         }#T_67db6_row40_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.9%, transparent 1.9%);
#         }#T_67db6_row43_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.8%, transparent 2.8%);
#         }</style><table id="T_67db6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >orgacom</th>        <th class="col_heading level0 col1" >origin</th>        <th class="col_heading level0 col2" >invalid</th>        <th class="col_heading level0 col3" >baseline</th>        <th class="col_heading level0 col4" >percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_67db6_level0_row0" class="row_heading level0 row0" >9</th>
#                         <td id="T_67db6_row0_col0" class="data row0 col0" >1ALO</td>
#                         <td id="T_67db6_row0_col1" class="data row0 col1" >#</td>
#                         <td id="T_67db6_row0_col2" class="data row0 col2" >21339</td>
#                         <td id="T_67db6_row0_col3" class="data row0 col3" >14019888</td>
#                         <td id="T_67db6_row0_col4" class="data row0 col4" >0.15%</td>
#             </tr>
#             <tr>
#                         <th id="T_67db6_level0_row1" class="row_heading level0 row1" >42</th>
#                         <td id="T_67db6_row1_col0" class="data row1 col0" >1ALO</td>
#                         <td id="T_67db6_row1_col1" class="data row1 col1" >TELE</td>
#                         <td id="T_67db6_row1_col2" class="data row1 col2" >5</td>
#                         <td id="T_67db6_row1_col3" class="data row1 col3" >14019888</td>
#                         <td id="T_67db6_row1_col4" class="data row1 col4" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_67db6_level0_row2" class="row_heading level0 row2" >32</th>
#                         <td id="T_67db6_row2_col0" class="data row2 col0" >1ALO</td>
#                         <td id="T_67db6_row2_col1" class="data row2 col1" >DFUE</td>
#                         <td id="T_67db6_row2_col2" class="data row2 col2" >3</td>
#                         <td id="T_67db6_row2_col3" class="data row2 col3" >14019888</td>
#                         <td id="T_67db6_row2_col4" class="data row2 col4" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_67db6_level0_row3" class="row_heading level0 row3" >13</th>
#                         <td id="T_67db6_row3_col0" class="data row3 col0" >1BFC</td>
#                         <td id="T_67db6_row3_col1" class="data row3 col1" >#</td>
# CPU times: user 15.6 s, sys: 1.86 s, total: 17.4 s
# Wall time: 2min 9s

# %%
# timed: 8min 59s...

# %%time
# with LocalCluster(
#     n_workers=int(0.9 * mp.cpu_count()),
#     processes=False,
#     threads_per_worker=1,
#     dashboard_address=':36000',
# #     memory_limit='2GB',
# #     ip='tcp://localhost:9895',
# ) as cluster, Client(cluster) as client:
#     display(ctrle_origin(raw_data).sort_values(['orgacom', 'origin']).style.format({'percentage': lambda x: f'{x:.2%}'}).bar(subset=['percentage'], align='mid', ))

# %% [markdown]
# ### Retraitement des avoirs

# %%
# from scripts import utils
# reload(utils)

# %%
# %%time

with LocalCluster(
    n_workers=int(0.9 * mp.cpu_count()),
    processes=True,
    threads_per_worker=1,
    dashboard_address=':36000',
) as cluster, Client(cluster) as client:
    processed_ddf = raw_data.map_partitions(
        process_df,
        meta=raw_data,
    )
# Out:
# CPU times: user 203 ms, sys: 182 ms, total: 385 ms
# Wall time: 2 s

# %%
# %%time

with LocalCluster(
    n_workers=int(0.9 * mp.cpu_count()),
    processes=True,
    threads_per_worker=1,
    dashboard_address=':36000',
) as cluster, Client(cluster) as client:
    processed_1ALO = (processed_ddf.loc[lambda x: x.orgacom == '1ALO'].compute())
    raw_1ALO = raw_data.loc[raw_data.orgacom == '1ALO'].compute()
# Out:
# CPU times: user 1min 31s, sys: 24.2 s, total: 1min 55s
# Wall time: 9min 2s

# %%
fig, axs = plt.subplots(nrows=2, figsize=(20, 12))
sns.lineplot(
    data=raw_1ALO.groupby(['date', 'origin'])[['weight', 'brutrevenue', 'margin']].sum(),
    x='date',
    y='margin',
    hue='origin',
    ax=axs[0],
)
sns.lineplot(
    data=processed_1ALO.groupby(['date', 'origin'])[['weight', 'brutrevenue', 'margin']].sum(),
    x='date',
    y='margin',
    hue='origin',
    ax=axs[1],
)
fig.suptitle('Illustration du nettoyage des avoirs - Succursale 1ALO')
# Out:
# Text(0.5, 0.98, 'Illustration du nettoyage des avoirs - Succursale 1ALO')

# %%
del(raw_1ALO, processed_1ALO)

# %% [markdown]
# ### Calcul des aggrégations
#
# On définit d'abord les fonctions des aggrégations à calculer (somme pour les indicateurs, + un indicateur pour compter les lignes), ainsi que les aggrégations :
# - orders : les commandes, au sens client x date x origine
# - pricetype : niveau commande avec en plus les types de prix initiaux et appliqués

# %%
aggfuncs = {
    'margin': 'sum', 
    'brutrevenue': 'sum',
    'weight': 'sum',
    'material': 'size',
}

agg_defs = {
    'orders': ['date', 'orgacom', 'client', 'origin'],
    'pricetype': ['date', 'orgacom', 'client', 'origin', 'pricetype_init', 'pricetype_applied']
}

# %%
# %%time

with LocalCluster(
    n_workers=int(0.9 * mp.cpu_count()),
    processes=True,
    threads_per_worker=1,
    dashboard_address=':36000',
) as cluster, Client(cluster) as client:
    filtered_ddf = (
        processed_ddf
        .loc[
            processed_ddf.origin.isin(valid_origins) & 
            (processed_ddf.brutrevenue > 0.) &
            (processed_ddf.weight > 0.)
        ]
    )
    for agg_name, groupers in agg_defs.items():
        (
            filtered_ddf
            .groupby(groupers, observed=True)
            .agg(aggfuncs, split_out=5)
            .rename(columns={'material': 'linecount'})
            .repartition(partition_size="100MB")
            .to_parquet(persist_path / (agg_name + '_all_SV.parquet'))
        )
# Out:
# tornado.application - ERROR - Uncaught exception GET /status/ws (10.201.12.72)
# HTTPServerRequest(protocol='http', host='devdm:35000', method='GET', uri='/status/ws', version='HTTP/1.1', remote_ip='10.201.12.72')
# Traceback (most recent call last):
#   File "/var/lib/anaconda3/envs/py38/lib/python3.8/site-packages/tornado/websocket.py", line 956, in _accept_connection
#     open_result = handler.open(*handler.open_args, **handler.open_kwargs)
#   File "/var/lib/anaconda3/envs/py38/lib/python3.8/site-packages/tornado/web.py", line 3178, in wrapper
#     return method(self, *args, **kwargs)
#   File "/var/lib/anaconda3/envs/py38/lib/python3.8/site-packages/bokeh/server/views/ws.py", line 137, in open
#     raise ProtocolError("Token is expired.")
# bokeh.protocol.exceptions.ProtocolError: Token is expired.
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing

# %%
### Ancienne version, plus nécessaire.

# order_groupers = ['orgacom', 'date', 'client', 'origin']  # pour les commandes, on considèrera ces clefs de regroupement
# order_df_list = []  # aggrégé par date, client, canal, orgacom 
# pricetype_groupers = ['orgacom', 'date', 'client', 'origin', 'pricetype_init', 'pricetype_applied']
# pricetype_df_list = []


# for orgacom in orgacom_list:
#     print('----------------------------------------------------------------')
#     print(f'{datetime.datetime.now()} - Début du traitement pour {orgacom}')
#     print('----------------------------------------------------------------')
#     print(f'{datetime.datetime.now()} - Lecture du fichier')
#     data = pd.read_pickle(persist_path / 'rawbyoc' / f'data_{orgacom}.pkl')
#     print(f'{datetime.datetime.now()} - Traitement des avoirs')
#     data = credit_processing(data)
#     print(f'{datetime.datetime.now()} - Application des filtres: CA > 0, origine de commande ok, poids > 0')
#     data = data.loc[
#         data.origin.isin(valid_origins) & 
#         (data.brutrevenue > 0) &
#         (data.weight > 0)
#     ]
#     print(f"{datetime.datetime.now()} - Calcul de l'aggrégation 'orders'")
#     order_df = data.groupby(order_groupers, observed=True).agg(aggfuncs).rename({'origin': 'linecount'}, axis=1)
#     order_df_list.append(order_df)
# #     print(f"{datetime.datetime.now()} - Calcul de l'aggrégation 'pricetype'")
# #     pricetype_df = data.groupby(pricetype_groupers, observed=True).agg(aggfuncs).rename({'origin': 'linecount'}, axis=1)
# #     pricetype_df_list.append(pricetype_df)

# pd.concat(order_df_list, axis=0).to_pickle(persist_path / 'orders_all_SV.pkl')

# %% [markdown]
# # Calcul du canal majoritaire en poids

# %%
raw_orders = dd.read_parquet(persist_path / 'orders_all_SV.parquet').compute()
raw_orders.head(10)
# Out:
#                                       margin  brutrevenue   weight  linecount
# origin date       client     orgacom
# VR     2017-07-01 0000060151 1LRO     225.10       763.76   83.470         20
# TV     2017-07-01 0000060162 1LRO     100.91       477.00   82.516         12
#                   0000060217 1LRO      94.66       257.19  112.000          4
#                   0000060230 1LRO     143.80      1337.77  178.182         11
#                   0000060330 1LRO      50.41       107.64   15.754          8
#                   0000060388 1LRO      14.61        96.36   14.000          2
# VR     2017-07-01 0000060429 1LRO      89.50       502.38   44.894          7
# TV     2017-07-01 0000060439 1LRO      25.04       141.93   12.898          2
# VR     2017-07-01 0000060477 1LRO     125.07       448.68   44.909          8
#                   0000060489 1LRO      18.17       278.65   26.100          2
#                   0000060574 1LRO      58.27       197.13   65.840          5
# TV     2017-07-01 0000060610 1LRO      76.79       275.78   60.710         10
# VR     2017-07-01 0000060621 1LRO      50.66       218.20   49.100          5
# TV     2017-07-01 0000060772 1LRO     130.69       440.58   58.201         19
# VR     2017-07-01 0000061222 1LRO     136.20       464.78  135.166         16
#                   0000061234 1LRO      72.77       229.37   37.408          9
# TV     2017-07-01 0000061260 1LRO      88.15       301.54   85.198         11
# VR     2017-07-01 0000061278 1LRO      57.61       161.49   31.809         11
# TV     2017-07-01 0000061339 1LRO      90.92       314.19   45.288         10
#                   0000061583 1LRO     235.99      1089.37  207.829         22
# VR     2017-07-01 0000061737 1LRO      12.73        33.60    4.460          2
# TV     2017-07-01 0000061973 1LRO     131.25       439.30  149.055         10
#                   0000063845 1LRO      70.25       368.53  194.804         11
#                   0000078120 1LRO     278.11       757.29  249.402         27
#                   0000079889 1LRO      10.84        57.87    9.097          4
#                   0000080417 1LRO      40.89       148.76   27.600          4
#                   0000084247 1LRO     136.75       681.32  255.342         22
#                   0000086535 1LRO      11.40        24.90    5.500          1
#                   0000093306 1LRO      22.19       209.40   30.000          2
# VR     2017-07-01 0000099176 1LRO     189.38       725.11  160.006          9
# TV     2017-07-01 0000099455 1LRO      16.45        94.79   24.540          9
# VR     2017-07-01 0000101983 1LRO     100.02       503.06  101.810         11
# TV     2017-07-01 0000102639 1LRO      26.60       148.95   18.000          4
#                   0000103143 1LRO      10.77        37.50    6.000          2
#                   0000103555 1LRO     163.39       664.78   91.488         19
# VR     2017-07-01 0000103854 1LRO      93.25       386.56   81.352         14
# TV     2017-07-01 0000122110 1LRO      56.07       215.52   19.564          3
#                   0000125827 1LRO       5.25        19.29   10.000          2
#                   0000131111 1LRO     171.84       469.59  106.201         12
#                   0000131338 1LRO       3.24        17.21    1.440          1
#                   0000131709 1LRO      62.51       709.33  376.611         34
# VR     2017-07-01 0000133417 1LRO      21.86       105.09   11.100          3
# TV     2017-07-01 0000133739 1LRO      12.50        35.40   12.000          1
#                   0000139867 1LRO     262.53       999.83  234.685         34
#                   0000144109 1LRO     428.03      1533.01  398.040          5
#                   0000146438 1LRO      21.37       156.96    9.900          1
# VR     2017-07-01 0000148192 1LRO      63.41       171.50   50.847         13
# TV     2017-07-01 0000156446 1LRO     110.95       461.09  177.030         18
#                   0000160178 1LRO      54.41       228.83   12.700          6
#                   0000160605 1LRO      10.11        18.90    0.720          1

# %%
print(f'Nb orders in initial dataset: {len(raw_orders)}')
target_len = len(raw_orders.reset_index().loc[:, ['orgacom', 'client', 'date']].drop_duplicates())
print(f'Target order count in order dataset: {target_len}')
# Out:
# Nb orders in initial dataset: 14391981
# Target order count in order dataset: 12767944

# %%
# about 1min 30s

# %%time
main_origin = (
    raw_orders['weight']
    .unstack('origin', fill_value=0)
    .idxmax(axis=1)
    .rename('main_origin')
)
# Out:
# CPU times: user 1min 34s, sys: 3.02 s, total: 1min 37s
# Wall time: 1min 35s

# %%
# about 4min 30s

# %%time
orders_with_main_origin = (
raw_orders
    .unstack('origin', fill_value=0)
    .rename_axis(('indicator', 'origin'), axis=1)
    .groupby('indicator', axis=1).sum()
).join(main_origin)
# Out:
# distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 13% CPU time recently (threshold: 10%)
# CPU times: user 3min 23s, sys: 1min 16s, total: 4min 39s
# Wall time: 4min 26s

# %% [markdown]
# On vérifie que le calcul du canal majoritaire n'a pas modifié les indicateurs au total :

# %%
check = orders_with_main_origin.iloc[:, :-1].join(raw_orders.groupby(['orgacom', 'date', 'client'], observed=True).sum(), rsuffix='_r')
for indicator in ['margin', 'brutrevenue', 'weight', 'linecount']:
    check[indicator + '_delta'] = (check[indicator] - check[indicator + '_r']).abs()
    assert(max(check[indicator + '_delta']) <= 0.00001)
del(check)

# %%
orders_with_main_origin.to_pickle(persist_path / 'orders_all_SV_with_main_origin.pkl')
