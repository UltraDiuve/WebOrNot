# %% [markdown]
# # 1. Objet
#
# Ce script retraite les données brutes enregistrées par le RawDataProcessor afin de :
# - contrôler la conformité à certaines règles de gestion métier
# - nettoyer les avoirs lorsque c'est possible
# - agréger les informations à une maille commande
# - calculer le canal majoritaire en poids
# - effectuer d'autres aggrégations si nécessaire (ex : types de tarif...)

# %% [markdown]
# # 2. Imports et setup technique

# %%
from pathlib import Path
import sys
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from importlib import reload
project_root = str(Path(sys.path[0]).parents[0].absolute())
project_root
if project_root not in sys.path:
    sys.path.append(project_root)
import multiprocessing as mp
    
from scripts.utils import process_df  # traitement des avoirs
    
data_path = Path('..') / 'data'
persist_path = Path('..') / 'persist'
from IPython.display import display, HTML
display(HTML("<style>.container { width:90%; }</style>"))

from dask.distributed import LocalCluster, Client
import dask.dataframe as dd
# Paramètres pour les traitements "tout-venant"
# std_client_kwargs = dict(
#     n_workers=int(0.9 * mp.cpu_count()),
#     processes=True,
#     threads_per_worker=2,
#     dashboard_address=':36000',
#     memory_limit='6GB',
# )
std_client_kwargs = dict(
    n_workers=4,
    processes=True,
    threads_per_worker=2,
    memory_limit='8GB',
    dashboard_address=':36000',
)



# Paramètres pour la constitution de l'index, gourmand en mémoire.
heavy_client_kwargs = dict(
    n_workers=1,
    threads_per_worker=2,
    processes=True,
    memory_limit='31GB',
    dashboard_address=':36000',
)
# Out:
# <style>.container { width:90%; }</style>

# %%
orgacom_list = [
    '1ALO',
    '1BFC',
    '1CAP',
    '1CTR',
    '1EXP',
    '1LRO',
    '1LXF',
    '1NCH',
    '1OUE',
    '1PAC',
#     '1PLU', 
    '1PNO',
    '1PSU',
    '1RAA',
    '1SOU',
    '2BRE',
    '2CAE',
    '2CTR',
    '2EST',
    '2IDF',
#     '2IFC', Cash Européenne Food ?
    '2MPY',
    '2NOR',
    '2RAA',
    '2SES',
    '2SOU',
]

# %% [markdown]
# # Chargement des données brutes

# %% [markdown]
# Il est possible de suivre l'avancement du traitement à l'url http://devdm:36000 (une fois le traitement lancé).

# %%
# %%time
with LocalCluster(**std_client_kwargs) as cluster, Client(cluster) as client_:
    raw_data = dd.read_parquet(persist_path / 'raw_data.parquet')
    print(f'Il y a {len(raw_data)} lignes dans le dataset')
# Out:
# Il y a 246155473 lignes dans le dataset
# CPU times: user 1.7 s, sys: 201 ms, total: 1.9 s
# Wall time: 9.34 s

# %%
# timed : 6,45s

# %%time
# with LocalCluster(
#     n_workers=int(0.9 * mp.cpu_count()),
#     processes=False,
#     threads_per_worker=1,
#     dashboard_address=':36000',
# #     memory_limit='2GB',
# #     ip='tcp://localhost:9895',
# ) as cluster, Client(cluster) as client_:
#     raw_data = dd.read_parquet(persist_path / 'raw_data.parquet')
#     print(f'Il y a {len(raw_data)} lignes dans le dataset')

# %% [markdown]
# Il est nécessaire de recharger les catégories à la lecture du fichier parquet.
# https://docs.dask.org/en/latest/dataframe-categoricals.html

# %%
for field in raw_data.dtypes.loc[lambda x: x == 'category'].index:
    raw_data[field] = raw_data[field].cat.set_categories(raw_data[field].head(1).cat.categories)

# %% [markdown]
# # Contrôle des données
#
# On définit les fonctions qui vont permettre d'effectuer les contrôles.
#
# ### Contrôle des types de documents

# %%
valid_doctypes = ['ZC01', 'ZC02', 'ZC10'] # documents de type "commandes"
invalid_doctypes = ['ZR01', 'ZR02', 'ZA01', 'ZA02', 'ZA03', 'ZA04', 'ZC20']  # autres types de documents
doctypes = valid_doctypes + invalid_doctypes

# %% [markdown]
# On s'assure qu'on n'a pas de type de document non prévu.

# %%
def ctrle_doctypes(data):
    if len(data.loc[~data.doctype.isin(doctypes)]) > 0:
        print(f'Unexpected doctypes have been encountered: '
              f'{data.loc[~data.doctype.isin(doctypes), "doctype"].value_counts().compute()}!')

# %%
# %%time
with LocalCluster(**std_client_kwargs) as cluster, Client(cluster) as client_: 
    ctrle_doctypes(raw_data)
# Out:
# Unexpected doctypes have been encountered: ZC04    223011
# ZA07      4064
# ZB1       2497
# ZB5       1155
# Name: doctype, dtype: int64!
# CPU times: user 21.6 s, sys: 1.75 s, total: 23.4 s
# Wall time: 4min 53s

# %% [markdown]
# ### Contrôle des CA bruts non nuls alors que le poids est nul
#
# D'un point de vue métier, il n'est pas possible qu'une ligne de **commande** (= valid_doctype) avec un poids nul ait un CA brut, sauf pour certains articles de service

# %%
def ctrle_no_weight_revenue(data, order_doctypes=valid_doctypes):
    return(
        data.loc[
            data.doctype.isin(order_doctypes) &
            (data.weight == 0) &
            (data.brutrevenue != 0)
        ]
        .compute()
        .groupby(['orgacom', 'material'], observed=True)
        .size()
        .to_frame()
    )

# %%
# %%time
with LocalCluster(**std_client_kwargs) as cluster, Client(cluster) as client_:
    result = ctrle_no_weight_revenue(raw_data)
# Out:
# CPU times: user 12.1 s, sys: 1.01 s, total: 13.2 s
# Wall time: 2min 18s

# %%
with pd.option_context('display.max_columns', None):
    display(result.unstack('orgacom', fill_value=0).sort_index(axis=1).style.bar(align='mid', axis=None))
# Out:
# <style  type="text/css" >
# #T_27de6_row0_col0,#T_27de6_row0_col1,#T_27de6_row0_col2,#T_27de6_row0_col3,#T_27de6_row0_col4,#T_27de6_row0_col5,#T_27de6_row0_col6,#T_27de6_row0_col7,#T_27de6_row0_col8,#T_27de6_row0_col9,#T_27de6_row0_col10,#T_27de6_row0_col11,#T_27de6_row0_col12,#T_27de6_row0_col13,#T_27de6_row0_col14,#T_27de6_row0_col15,#T_27de6_row0_col16,#T_27de6_row0_col18,#T_27de6_row0_col19,#T_27de6_row0_col20,#T_27de6_row0_col21,#T_27de6_row1_col0,#T_27de6_row1_col1,#T_27de6_row1_col2,#T_27de6_row1_col3,#T_27de6_row1_col4,#T_27de6_row1_col5,#T_27de6_row1_col6,#T_27de6_row1_col7,#T_27de6_row1_col8,#T_27de6_row1_col9,#T_27de6_row1_col10,#T_27de6_row1_col12,#T_27de6_row1_col13,#T_27de6_row1_col14,#T_27de6_row1_col15,#T_27de6_row1_col16,#T_27de6_row1_col17,#T_27de6_row1_col18,#T_27de6_row1_col19,#T_27de6_row1_col20,#T_27de6_row1_col21,#T_27de6_row2_col0,#T_27de6_row2_col1,#T_27de6_row2_col2,#T_27de6_row2_col3,#T_27de6_row2_col4,#T_27de6_row2_col5,#T_27de6_row2_col6,#T_27de6_row2_col7,#T_27de6_row2_col8,#T_27de6_row2_col9,#T_27de6_row2_col10,#T_27de6_row2_col11,#T_27de6_row2_col12,#T_27de6_row2_col13,#T_27de6_row2_col14,#T_27de6_row2_col15,#T_27de6_row2_col16,#T_27de6_row2_col17,#T_27de6_row2_col19,#T_27de6_row2_col20,#T_27de6_row2_col21,#T_27de6_row3_col0,#T_27de6_row3_col1,#T_27de6_row3_col2,#T_27de6_row3_col3,#T_27de6_row3_col4,#T_27de6_row3_col5,#T_27de6_row3_col6,#T_27de6_row3_col7,#T_27de6_row3_col8,#T_27de6_row3_col9,#T_27de6_row3_col10,#T_27de6_row3_col11,#T_27de6_row3_col12,#T_27de6_row3_col13,#T_27de6_row3_col14,#T_27de6_row3_col15,#T_27de6_row3_col16,#T_27de6_row3_col17,#T_27de6_row3_col18,#T_27de6_row3_col20,#T_27de6_row4_col0,#T_27de6_row4_col1,#T_27de6_row4_col2,#T_27de6_row4_col3,#T_27de6_row4_col4,#T_27de6_row4_col5,#T_27de6_row4_col6,#T_27de6_row4_col7,#T_27de6_row4_col8,#T_27de6_row4_col9,#T_27de6_row4_col10,#T_27de6_row4_col11,#T_27de6_row4_col12,#T_27de6_row4_col13,#T_27de6_row4_col14,#T_27de6_row4_col15,#T_27de6_row4_col16,#T_27de6_row4_col17,#T_27de6_row4_col19,#T_27de6_row4_col20,#T_27de6_row4_col21,#T_27de6_row5_col0,#T_27de6_row5_col1,#T_27de6_row5_col2,#T_27de6_row5_col3,#T_27de6_row5_col4,#T_27de6_row5_col5,#T_27de6_row5_col6,#T_27de6_row5_col7,#T_27de6_row5_col8,#T_27de6_row5_col9,#T_27de6_row5_col10,#T_27de6_row5_col11,#T_27de6_row5_col12,#T_27de6_row5_col13,#T_27de6_row5_col14,#T_27de6_row5_col15,#T_27de6_row5_col16,#T_27de6_row5_col17,#T_27de6_row5_col18,#T_27de6_row5_col19,#T_27de6_row5_col21,#T_27de6_row6_col0,#T_27de6_row6_col1,#T_27de6_row6_col2,#T_27de6_row6_col3,#T_27de6_row6_col4,#T_27de6_row6_col5,#T_27de6_row6_col6,#T_27de6_row6_col7,#T_27de6_row6_col8,#T_27de6_row6_col9,#T_27de6_row6_col10,#T_27de6_row6_col11,#T_27de6_row6_col12,#T_27de6_row6_col16,#T_27de6_row7_col0,#T_27de6_row7_col1,#T_27de6_row7_col2,#T_27de6_row7_col3,#T_27de6_row7_col4,#T_27de6_row7_col5,#T_27de6_row7_col6,#T_27de6_row7_col7,#T_27de6_row7_col9,#T_27de6_row7_col10,#T_27de6_row7_col11,#T_27de6_row7_col12,#T_27de6_row7_col13,#T_27de6_row7_col14,#T_27de6_row7_col15,#T_27de6_row7_col16,#T_27de6_row7_col17,#T_27de6_row7_col18,#T_27de6_row7_col19,#T_27de6_row7_col20,#T_27de6_row7_col21,#T_27de6_row8_col0,#T_27de6_row8_col1,#T_27de6_row8_col3,#T_27de6_row8_col4,#T_27de6_row8_col5,#T_27de6_row8_col6,#T_27de6_row8_col7,#T_27de6_row8_col8,#T_27de6_row8_col9,#T_27de6_row8_col10,#T_27de6_row8_col11,#T_27de6_row8_col12,#T_27de6_row8_col13,#T_27de6_row8_col14,#T_27de6_row8_col15,#T_27de6_row8_col16,#T_27de6_row8_col17,#T_27de6_row8_col18,#T_27de6_row8_col19,#T_27de6_row8_col20,#T_27de6_row8_col21,#T_27de6_row9_col0,#T_27de6_row9_col1,#T_27de6_row9_col2,#T_27de6_row9_col3,#T_27de6_row9_col4,#T_27de6_row9_col5,#T_27de6_row9_col6,#T_27de6_row9_col9,#T_27de6_row9_col10,#T_27de6_row9_col11,#T_27de6_row9_col12,#T_27de6_row9_col13,#T_27de6_row9_col14,#T_27de6_row9_col15,#T_27de6_row9_col16,#T_27de6_row9_col17,#T_27de6_row9_col18,#T_27de6_row9_col19,#T_27de6_row9_col20,#T_27de6_row9_col21,#T_27de6_row10_col0,#T_27de6_row10_col1,#T_27de6_row10_col2,#T_27de6_row10_c ...

# %% [markdown]
# L'essentiel des articles concernés sont des articles de service (forfaits livraison). Il faudrait regarder ce qui s'est passé sur le 156486, il remonte régulièrement côté ES.

# %% [markdown]
# ### Contrôle des origines de commande

# %%
valid_origins = ['TV', 'VR', 'WEB', 'EDI']

def ctrle_origin(data, valid_origins=valid_origins):
    sizes = (
        data.loc[
            (data.brutrevenue != 0) &
            data.doctype.isin(valid_doctypes)
        ].groupby(['orgacom'], observed=True).size()
        .compute()
    ).rename('baseline')
    
    invalid_origins = (
        data.loc[
            (data.brutrevenue != 0) &
            data.doctype.isin(valid_doctypes) &
            ~data.origin.isin(valid_origins)
        ].groupby(['orgacom', 'origin'], observed=True).size()
        .compute()    
    ).rename('invalid').to_frame()
    invalid_origins = invalid_origins.reset_index().merge(sizes.reset_index(), on='orgacom', how='left')
    invalid_origins['percentage'] = invalid_origins['invalid'] / invalid_origins['baseline']
    return(invalid_origins)

# %% [markdown]
# On contrôle que les origines de commande "exotiques" sont minoritaire sur le dataset.

# %%
# %%time
with LocalCluster(**std_client_kwargs) as cluster, Client(cluster) as client_:
    display(ctrle_origin(raw_data).sort_values(['orgacom', 'origin']).style.format({'percentage': lambda x: f'{x:.2%}'}).bar(subset=['percentage'], align='mid', ))
# Out:
# <style  type="text/css" >
# #T_9032b_row0_col4,#T_9032b_row5_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.1%, transparent 0.1%);
#         }#T_9032b_row1_col4,#T_9032b_row8_col4,#T_9032b_row18_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }#T_9032b_row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 61.2%, transparent 61.2%);
#         }#T_9032b_row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.0%, transparent 1.0%);
#         }#T_9032b_row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.5%, transparent 1.5%);
#         }#T_9032b_row6_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }#T_9032b_row7_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0.8%);
#         }#T_9032b_row9_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0.3%);
#         }#T_9032b_row10_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_9032b_row11_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 38.6%, transparent 38.6%);
#         }#T_9032b_row12_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 77.5%, transparent 77.5%);
#         }#T_9032b_row13_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.9%, transparent 12.9%);
#         }#T_9032b_row14_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 36.5%, transparent 36.5%);
#         }#T_9032b_row15_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 50.4%, transparent 50.4%);
#         }#T_9032b_row16_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 52.6%, transparent 52.6%);
#         }#T_9032b_row17_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 29.1%, transparent 29.1%);
#         }#T_9032b_row19_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 42.4%, transparent 42.4%);
#         }</style><table id="T_9032b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >orgacom</th>        <th class="col_heading level0 col1" >origin</th>        <th class="col_heading level0 col2" >invalid</th>        <th class="col_heading level0 col3" >baseline</th>        <th class="col_heading level0 col4" >percentage</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9032b_level0_row0" class="row_heading level0 row0" >18</th>
#                         <td id="T_9032b_row0_col0" class="data row0 col0" >1ALO</td>
#                         <td id="T_9032b_row0_col1" class="data row0 col1" >TELE</td>
#                         <td id="T_9032b_row0_col2" class="data row0 col2" >5</td>
#                         <td id="T_9032b_row0_col3" class="data row0 col3" >14951326</td>
#                         <td id="T_9032b_row0_col4" class="data row0 col4" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_9032b_level0_row1" class="row_heading level0 row1" >8</th>
#                         <td id="T_9032b_row1_col0" class="data row1 col0" >1ALO</td>
#                         <td id="T_9032b_row1_col1" class="data row1 col1" >DFUE</td>
#                         <td id="T_9032b_row1_col2" class="data row1 col2" >3</td>
#                         <td id="T_9032b_row1_col3" class="data row1 col3" >14951326</td>
#                         <td id="T_9032b_row1_col4" class="data row1 col4" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_9032b_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9032b_row2_col0" class="data row2 col0" >1CAP</td>
#                         <td id="T_9032b_row2_col1" class="data row2 col1" >SCHR</td>
#                         <td id="T_9032b_row2_col2" class="data row2 col2" >100</td>
#                         <td id="T_9032b_row2_col3" class="data row2 col3" >329655</td>
#                         <td id="T_9032b_row2_col4" class="data row2 col4" >0.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_9032b_level0_row3" class="row_heading level0 row3" >11</th>
#                         <td id="T_9032b_row3_col0" class="data row3 col0" >1CTR</td>
#                         <td id="T_9032b_row3_col1" class="data row3 col1" >DFUE</td>
#                         <td id="T_9032b_row3_col2" class="data row3 col2" >39</td>
#                         <td id="T_9032b_row3_col3" class="data row3 col3" >7936828</td>
#                         <td id="T_9032b_row3_col4" class="data row3 col4" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_9032b_level0_row4" class="row_heading level0 row4" >10</th>
#                         <td id="T_9032b_row4_col0" class="data row4 col0" >1NCH</td>
#                         <td id="T_9032b_row4_col1" class="data row4 col1" >SCHR</td>
#                         <td id="T_9032b_row4_col2" class="data row4 col2" >85</td>
#                         <td id="T_9032b_row4_col3" class="data row4 col3" >11628415</td>
#                         <td id="T_9032b_row4_col4" class="data row4 col4" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_9032b_level0_row5" class="row_heading level0 row5" >9</th>
#                         <td id="T_9032b_row5_col0" class="data row5 col0" >1PSU</td>
#                         <td id="T_9032b_row5_col1" class="data row5 col1" >DFUE</td>
#                         <td id="T_9032b_row5_col2" class="data row5 col2" >8</td>
#                         <td id="T_9032b_row5_col3" class="data row5 col3" >16415373</td>
#                         <td id="T_9032b_row5_col4" class="data row5 col4" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_9032b_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_9032b_row6_col0" class="data row6 col0" >1RAA</td>
#                         <td id="T_9032b_row6_col1" class="data row6 col1" >SCHR</td>
#                         <td id="T_9032b_row6_col2" class="data row6 col2" >22</td>
#                         <td id="T_9032b_row6_col3" class="data row6 col3" >18052798</td>
#                         <td id="T_9032b_row6_col4" class="data row6 col4" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_9032b_level0_row7" class="row_heading level0 row7" >5</th>
#                         <td id="T_9032b_row7_col0" class="data row7 col0" >1RAA</td>
#                         <td id="T_9032b_row7_col1" class="data row7 col1" >TELE</td>
#                         <td id="T_9032b_row7_col2" class="data row7 col2" >76</td>
#                         <td id="T_9032b_row7_col3" class="data row7 col3" >18052798</td>
#                         <td id="T_9032b_row7_col4" class="data row7 col4" >0.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_9032b_level0_row8" class="row_heading level0 row8" >19</th>
#                         <td id="T_9032b_row8_col0" class="data row8 col0" >1RAA</td>
#                         <td id="T_9032b_row8_col1" class="data row8 col1" >MUEN</td>
# CPU times: user 18.5 s, sys: 1.93 s, total: 20.4 s
# Wall time: 5min 20s

# %% [markdown]
# ### Retraitement des avoirs

# %% [markdown]
# On lance le retraitement des avoirs. La règle de gestion est qu'on va combiner le montant du tonnage, CA et marge des avoirs aux commandes si on est dans la situation suivante :
# - l'avoir est passé pour le même article, le même client (et organisation commerciale) et le même jour que le poste de commande à combiner
# - il n'y a qu'un seul poste de commande existant pour ces critères (contre exemple : l'article a fait l'objet d'une commande sur 2 canaux distincts, on ne sait pas auquel affecter l'avoir)
# - le CA brut et le tonnage du poste de commande résiduel doivent être tous les deux supérieurs ou égal 0

# %%
processed_ddf = raw_data.map_partitions(
    process_df,
    meta=raw_data,
)

# %% [markdown]
# Les cellules ci-dessous produisent des graphes pour illustrer le traitement, leur exécution n'est pas indispensable.

# %%
# %%time

# with LocalCluster(**std_client_kwargs) as cluster, Client(cluster) as client_:
#     processed_1ALO = (processed_ddf.loc[lambda x: x.orgacom == '1ALO'].compute())
#     raw_1ALO = raw_data.loc[raw_data.orgacom == '1ALO'].compute()

# %%
# fig, axs = plt.subplots(nrows=2, figsize=(20, 12))
# sns.lineplot(
#     data=raw_1ALO.groupby(['date', 'origin'])[['weight', 'brutrevenue', 'margin']].sum(),
#     x='date',
#     y='margin',
#     hue='origin',
#     ax=axs[0],
# )
# sns.lineplot(
#     data=processed_1ALO.groupby(['date', 'origin'])[['weight', 'brutrevenue', 'margin']].sum(),
#     x='date',
#     y='margin',
#     hue='origin',
#     ax=axs[1],
# )
# fig.suptitle('Illustration du nettoyage des avoirs - Succursale 1ALO')

# %%
# del(raw_1ALO, processed_1ALO)

# %% [markdown]
# ### Calcul des aggrégations
#
# On définit d'abord les fonctions des aggrégations à calculer (somme pour les indicateurs, + un indicateur pour compter les lignes), ainsi que les aggrégations :
# - orders : les commandes, au sens client x date x origine
# - pricetype : niveau commande avec en plus les types de prix initiaux et appliqués. Cette aggrégation a été désactivé dans le dictionnaire ci-dessous, car elle n'est pas utilisée.

# %%
aggfuncs = {
    'margin': 'sum', 
    'brutrevenue': 'sum',
    'weight': 'sum',
    'material': 'size',
}

agg_defs = {
    'orders': ['date', 'orgacom', 'client', 'origin'],
#     'pricetype': ['date', 'orgacom', 'client', 'origin', 'pricetype_init', 'pricetype_applied']
}

# %%
# %%time
# around 80 minutes for 'orders' aggregation only.

with LocalCluster(**std_client_kwargs) as cluster, Client(cluster) as client_:
    filtered_ddf = (
        processed_ddf
        .loc[
            processed_ddf.origin.isin(valid_origins) & 
            (processed_ddf.brutrevenue > 0.) &
            (processed_ddf.weight > 0.)
        ]
    )
    for agg_name, groupers in agg_defs.items():
        (
            filtered_ddf
            .groupby(groupers, observed=True)
            .agg(aggfuncs, split_out=5)
            .reset_index()
            .rename(columns={'material': 'linecount'})
            .set_index('date')
            .repartition(partition_size="100MB")
            .to_parquet(
                persist_path / (agg_name + '_all_SV.parquet'),
                overwrite=True,
                engine='fastparquet',         
            )
        )
# Out:
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# CPU times: user 9min 9s, sys: 40.1 s, total: 9min 49s
# Wall time: 1h 21min 26s

# %%
### Ancienne version, plus nécessaire.

# order_groupers = ['orgacom', 'date', 'client', 'origin']  # pour les commandes, on considèrera ces clefs de regroupement
# order_df_list = []  # aggrégé par date, client, canal, orgacom 
# pricetype_groupers = ['orgacom', 'date', 'client', 'origin', 'pricetype_init', 'pricetype_applied']
# pricetype_df_list = []


# for orgacom in orgacom_list:
#     print('----------------------------------------------------------------')
#     print(f'{datetime.datetime.now()} - Début du traitement pour {orgacom}')
#     print('----------------------------------------------------------------')
#     print(f'{datetime.datetime.now()} - Lecture du fichier')
#     data = pd.read_pickle(persist_path / 'rawbyoc' / f'data_{orgacom}.pkl')
#     print(f'{datetime.datetime.now()} - Traitement des avoirs')
#     data = credit_processing(data)
#     print(f'{datetime.datetime.now()} - Application des filtres: CA > 0, origine de commande ok, poids > 0')
#     data = data.loc[
#         data.origin.isin(valid_origins) & 
#         (data.brutrevenue > 0) &
#         (data.weight > 0)
#     ]
#     print(f"{datetime.datetime.now()} - Calcul de l'aggrégation 'orders'")
#     order_df = data.groupby(order_groupers, observed=True).agg(aggfuncs).rename({'origin': 'linecount'}, axis=1)
#     order_df_list.append(order_df)
# #     print(f"{datetime.datetime.now()} - Calcul de l'aggrégation 'pricetype'")
# #     pricetype_df = data.groupby(pricetype_groupers, observed=True).agg(aggfuncs).rename({'origin': 'linecount'}, axis=1)
# #     pricetype_df_list.append(pricetype_df)

# pd.concat(order_df_list, axis=0).to_pickle(persist_path / 'orders_all_SV.pkl')

# %% [markdown]
# # Calcul du canal majoritaire en poids

# %%
raw_orders = dd.read_parquet(persist_path / 'orders_all_SV.parquet').compute()
raw_orders.head(10)
# Out:
#            orgacom      client origin  margin  brutrevenue   weight  linecount
# date
# 2017-07-01    1LRO  0000060151     VR  225.10       763.76   83.470         20
# 2017-07-01    1LRO  0000211118     VR   81.63       230.69   47.716         13
# 2017-07-01    1LRO  0000210623     TV   85.88       273.32   43.080         13
# 2017-07-01    1LRO  0000210124     TV  213.51       798.87   93.174         17
# 2017-07-01    1LRO  0000210071     TV   81.48       178.88   18.663         10
# 2017-07-01    1LRO  0000209507     VR   68.93       208.51   39.714         16
# 2017-07-01    1LRO  0000208718     TV   14.89        80.30    8.140          3
# 2017-07-01    1LRO  0000208444     VR   26.43        68.94    5.872          3
# 2017-07-01    1LRO  0000207557     VR   42.15       133.00   23.660          4
# 2017-07-01    1LRO  0000202457     VR  294.38      1166.80  122.959         23

# %%
print(f'Nb orders in initial dataset: {len(raw_orders)}')
target_len = len(raw_orders.reset_index().loc[:, ['orgacom', 'client', 'date']].drop_duplicates())
print(f'Target order count in order dataset: {target_len}')
# Out:
# Nb orders in initial dataset: 15396408
# Target order count in order dataset: 13648307

# %%
# %%time
# about 1min 45s

main_origin = (
    raw_orders
    .set_index(['orgacom', 'client', 'origin'], append=True)
    ['weight']
    .unstack('origin', fill_value=0)
    .idxmax(axis=1)
    .rename('main_origin')
)
# Out:
# CPU times: user 1min 39s, sys: 5.64 s, total: 1min 45s
# Wall time: 1min 45s

# %%
raw_orders
# Out:
#            orgacom      client origin  margin  brutrevenue   weight  linecount
# date
# 2017-07-01    1LRO  0000060151     VR  225.10       763.76   83.470         20
# 2017-07-01    1LRO  0000211118     VR   81.63       230.69   47.716         13
# 2017-07-01    1LRO  0000210623     TV   85.88       273.32   43.080         13
# 2017-07-01    1LRO  0000210124     TV  213.51       798.87   93.174         17
# 2017-07-01    1LRO  0000210071     TV   81.48       178.88   18.663         10
# ...            ...         ...    ...     ...          ...      ...        ...
# 2021-05-31    1BFC  0000029484     TV  111.21       515.19   83.630         10
# 2021-05-31    1BFC  0000019288     TV   19.27       132.53   35.377          4
# 2021-05-31    1BFC  0000019204    EDI   14.41        83.22   41.000          8
# 2021-05-31    1BFC  0000055460     TV   37.83       597.28  114.374         17
# 2021-05-31    2SOU     P041807     TV   -4.15        81.95   34.888         16
#
# [15396408 rows x 7 columns]

# %%
# %%time
# about 3min 30s

orders_with_main_origin = (
    raw_orders
    .set_index(['orgacom', 'client', 'origin'], append=True)
    .unstack('origin', fill_value=0)
    .rename_axis(('indicator', 'origin'), axis=1)
    .groupby('indicator', axis=1).sum()
).join(main_origin)
# Out:
# CPU times: user 3min 17s, sys: 1min 29s, total: 4min 46s
# Wall time: 4min 43s

# %% [markdown]
# On vérifie que le calcul du canal majoritaire n'a pas modifié les indicateurs au total (la cellule suivante lève une exception en cas d'écart).

# %%
# %%time
# about 3min 30s

check = orders_with_main_origin.iloc[:, :-1].join(raw_orders.groupby(['orgacom', 'date', 'client'], observed=True).sum(), rsuffix='_r')
for indicator in ['margin', 'brutrevenue', 'weight', 'linecount']:
    check[indicator + '_delta'] = (check[indicator] - check[indicator + '_r']).abs()
    assert(max(check[indicator + '_delta']) <= 0.00001)
del(check)
# Out:
# CPU times: user 2min 3s, sys: 1min 21s, total: 3min 25s
# Wall time: 3min 23s

# %% [markdown]
# On peut contrôler que ce retraitement a bien produit le nombre de lignes initialement prévu (quelques cellules plus haut).

# %%
print(
    f"Order count in order dataset: {len(orders_with_main_origin)}"
)
# Out:
# Order count in order dataset: 13648307

# %%
orders_with_main_origin.to_pickle(persist_path / 'orders_all_SV_with_main_origin.pkl')
